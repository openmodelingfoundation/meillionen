# %%
import numpy as np
from landlab import RasterModelGrid
from landlab.components.overland_flow import OverlandFlow
from landlab.plot.imshow import imshow_grid
from matplotlib.pyplot import figure

# %% [markdown]
# First we need to load in the weather data and find the only days where there is rain

# %%
import pandas as pd

weather = pd.read_fwf("weather.txt")

# find the days that have positive precipitation

days_with_rain = weather['rain'][weather['rain'] > 0]
days_with_rain = days_with_rain[days_with_rain.index.isin(range(0, 365))]
days_with_rain
# Out:
# 0      23.9
# 3      14.7
# 4       0.8
# 9       3.8
# 15      6.3
#        ...
# 329     2.0
# 343     1.3
# 348    24.9
# 355     0.5
# 361     3.3
# Name: rain, Length: 106, dtype: float64

# %%
days_with_rain.index[1]
# Out:
# 3

# %%
import netCDF4

class Overland:
    def __init__(self):
        self.shape = (20, 20)
        self.shape_used = (range(2,18), range(2,18))
        self.input = {}
        
    def set_value(self, name, value):
        if name != 'rainfall__depth':
            raise KeyError('"rainfall__depth" is the only valid setter')
        self.input[name] = value
    
    def initialize(self):
        outfile = netCDF4.Dataset('overland.nc', 'w')
        xs, ys = self.shape_used
        outfile.createDimension('x', len(xs))
        outfile.createDimension('y', len(ys))
        self.time_dimension =  outfile.createDimension('time', 365)
#         self.time_dimension.units = 'day'
        self.surface_water__depth = outfile.createVariable('surface_water__depth', 'f4', ('x', 'y', 'time'))
#         self.surface_water__depth.units = 'millimetre'
        self.output = outfile  
    
    def run(self, rainfall_mmhr):
        grid = RasterModelGrid(self.shape)
        topo = np.zeros(self.shape)
        topo[4, 5] = 0.05
        topo[13,3] = 0.1
        grid.at_node['topographic__elevation'] = topo
        grid.at_node['surface_water__depth'] = np.zeros(self.shape)
        
        elapsed_time = 0.0
        model_run_time = 7200.0

        storm_duration = 7200.0
        of = OverlandFlow(grid, steep_slopes=True, rainfall_intensity=rainfall_mmhr * (1/3600 * 1/1000))
        
        while elapsed_time < model_run_time:
            of.dt = of.calc_time_step()     # Adaptive time step

            if elapsed_time > storm_duration:
                of.rainfall_intensity = 0.0

            of.overland_flow()
            elapsed_time += of.dt

        xs, ys = self.shape_used
        
        return grid.at_node['surface_water__depth'].reshape(self.shape)[xs[0]:xs[1], ys[0]:ys[1]]
        
    def update(self):
        rainfall = self.input['rainfall__depth']
        for ind in range(365):
            if ind in rainfall.index:
                grid = self.run(rainfall[ind])
                self.surface_water__depth[:, :, ind] = grid
            else:
                xsize = len(self.shape_used[0])
                ysize = len(self.shape_used[1])
                grid = np.zeros((xsize, ysize))
                self.surface_water__depth[:, :, ind] = grid

# %%
import os

os.unlink('overland.nc')

of = Overland()
of.set_value('rainfall__depth', days_with_rain)

# %%
of.initialize()
of.update()
# Out:
# routing rainfall at t=0
# routing rainfall at t=1
# routing rainfall at t=2
# routing rainfall at t=3
# routing rainfall at t=4
# routing rainfall at t=5
# routing rainfall at t=6
# routing rainfall at t=7
# routing rainfall at t=8
# routing rainfall at t=9
# routing rainfall at t=10
# routing rainfall at t=11
# routing rainfall at t=12
# routing rainfall at t=13
# routing rainfall at t=14
# routing rainfall at t=15
# routing rainfall at t=16
# routing rainfall at t=17
# routing rainfall at t=18
# routing rainfall at t=19
# routing rainfall at t=20
# routing rainfall at t=21
# routing rainfall at t=22
# routing rainfall at t=23
# routing rainfall at t=24
# routing rainfall at t=25
# routing rainfall at t=26
# routing rainfall at t=27
# routing rainfall at t=28
# routing rainfall at t=29
# routing rainfall at t=30
# routing rainfall at t=31
# routing rainfall at t=32
# routing rainfall at t=33
# routing rainfall at t=34
# routing rainfall at t=35
# routing rainfall at t=36
# routing rainfall at t=37
# routing rainfall at t=38
# routing rainfall at t=39
# routing rainfall at t=40
# routing rainfall at t=41
# routing rainfall at t=42
# routing rainfall at t=43
# routing rainfall at t=44
# routing rainfall at t=45
# routing rainfall at t=46
# routing rainfall at t=47
# routing rainfall at t=48
# routing rainfall at t=49
# routing rainfall at t=50
# routing rainfall at t=51
# routing rainfall at t=52
# routing rainfall at t=53
# routing rainfall at t=54
# routing rainfall at t=55
# routing rainfall at t=56
# routing rainfall at t=57
# routing rainfall at t=58
# routing rainfall at t=59
# routing rainfall at t=60
# routing rainfall at t=61
# routing rainfall at t=62
# routing rainfall at t=63
# routing rainfall at t=64
# routing rainfall at t=65
# routing rainfall at t=66
# routing rainfall at t=67
# routing rainfall at t=68
# routing rainfall at t=69
# routing rainfall at t=70
# routing rainfall at t=71
# routing rainfall at t=72
# routing rainfall at t=73
# routing rainfall at t=74
# routing rainfall at t=75
# routing rainfall at t=76
# routing rainfall at t=77
# routing rainfall at t=78
# routing rainfall at t=79
# routing rainfall at t=80
# routing rainfall at t=81
# routing rainfall at t=82
# routing rainfall at t=83
# routing rainfall at t=84
# routing rainfall at t=85
# routing rainfall at t=86
# routing rainfall at t=87
# routing rainfall at t=88
# routing rainfall at t=89
# routing rainfall at t=90
# routing rainfall at t=91
# routing rainfall at t=92
# routing rainfall at t=93
# routing rainfall at t=94
# routing rainfall at t=95
# routing rainfall at t=96
# routing rainfall at t=97
# routing rainfall at t=98
# routing rainfall at t=99
# routing rainfall at t=100
# routing rainfall at t=101
# routing rainfall at t=102
# routing rainfall at t=103
# routing rainfall at t=104
# routing rainfall at t=105
# routing rainfall at t=106
# routing rainfall at t=107
# routing rainfall at t=108
# routing rainfall at t=109
# routing rainfall at t=110
# routing rainfall at t=111
# routing rainfall at t=112
# routing rainfall at t=113
# routing rainfall at t=114
# routing rainfall at t=115
# routing rainfall at t=116
# routing rainfall at t=117
# routing rainfall at t=118
# routing rainfall at t=119
# routing rainfall at t=120
# routing rainfall at t=121
# routing rainfall at t=122
# routing rainfall at t=123
# routing rainfall at t=124
# routing rainfall at t=125
# routing rainfall at t=126
# routing rainfall at t=127
# routing rainfall at t=128
# routing rainfall at t=129
# routing rainfall at t=130
# routing rainfall at t=131
# routing rainfall at t=132
# routing rainfall at t=133
# routing rainfall at t=134
# routing rainfall at t=135
# routing rainfall at t=136
# routing rainfall at t=137
# routing rainfall at t=138
# routing rainfall at t=139
# routing rainfall at t=140
# routing rainfall at t=141
# routing rainfall at t=142
# routing rainfall at t=143
# routing rainfall at t=144
# routing rainfall at t=145
# routing rainfall at t=146
# routing rainfall at t=147
# routing rainfall at t=148
# routing rainfall at t=149
# routing rainfall at t=150
# routing rainfall at t=151
# routing rainfall at t=152
# routing rainfall at t=153
# routing rainfall at t=154
# routing rainfall at t=155
# routing rainfall at t=156
# routing rainfall at t=157
# routing rainfall at t=158
# routing rainfall at t=159
# routing rainfall at t=160
# routing rainfall at t=161
# routing rainfall at t=162
# routing rainfall at t=163
# routing rainfall at t=164
# routing rainfall at t=165
# routing rainfall at t=166
# routing rainfall at t=167
# routing rainfall at t=168
# routing rainfall at t=169
# routing rainfall at t=170
# routing rainfall at t=171
# routing rainfall at t=172
# routing rainfall at t=173
# routing rainfall at t=174
# routing rainfall at t=175
# routing rainfall at t=176
# routing rainfall at t=177
# routing rainfall at t=178
# routing rainfall at t=179
# routing rainfall at t=180
# routing rainfall at t=181
# routing rainfall at t=182
# routing rainfall at t=183
# routing rainfall at t=184
# routing rainfall at t=185
# routing rainfall at t=186
# routing rainfall at t=187
# routing rainfall at t=188
# routing rainfall at t=189
# routing rainfall at t=190
# routing rainfall at t=191
# routing rainfall at t=192
# routing rainfall at t=193
# routing rainfall at t=194
# routing rainfall at t=195
# routing rainfall at t=196
# routing rainfall at t=197
# routing rainfall at t=198
# routing rainfall at t=199
# routing rainfall at t=200
# routing rainfall at t=201
# routing rainfall at t=202
# routing rainfall at t=203
# routing rainfall at t=204
# routing rainfall at t=205
# routing rainfall at t=206
# routing rainfall at t=207
# routing rainfall at t=208
# routing rainfall at t=209
# routing rainfall at t=210
# routing rainfall at t=211
# routing rainfall at t=212
# routing rainfall at t=213
# routing rainfall at t=214
# routing rainfall at t=215
# routing rainfall at t=216
# routing rainfall at t=217
# routing rainfall at t=218
# routing rainfall at t=219
# routing rainfall at t=220
# routing rainfall at t=221
# routing rainfall at t=222
# routing rainfall at t=223
# routing rainfall at t=224
# routing rainfall at t=225
# routing rainfall at t=226
# routing rainfall at t=227
# routing rainfall at t=228
# routing rainfall at t=229
# routing rainfall at t=230
# routing rainfall at t=231
# routing rainfall at t=232
# routing rainfall at t=233
# routing rainfall at t=234
# routing rainfall at t=235
# routing rainfall at t=236
# routing rainfall at t=237
# routing rainfall at t=238
# routing rainfall at t=239
# routing rainfall at t=240
# routing rainfall at t=241
# routing rainfall at t=242
# routing rainfall at t=243
# routing rainfall at t=244
# routing rainfall at t=245
# routing rainfall at t=246
# routing rainfall at t=247
# routing rainfall at t=248
# routing rainfall at t=249
# routing rainfall at t=250
# routing rainfall at t=251
# routing rainfall at t=252
# routing rainfall at t=253
# routing rainfall at t=254
# routing rainfall at t=255
# routing rainfall at t=256
# routing rainfall at t=257
# routing rainfall at t=258
# routing rainfall at t=259
# routing rainfall at t=260
# routing rainfall at t=261
# routing rainfall at t=262
# routing rainfall at t=263
# routing rainfall at t=264
# routing rainfall at t=265
# routing rainfall at t=266
# routing rainfall at t=267
# routing rainfall at t=268
# routing rainfall at t=269
# routing rainfall at t=270
# routing rainfall at t=271
# routing rainfall at t=272
# routing rainfall at t=273
# routing rainfall at t=274
# routing rainfall at t=275
# routing rainfall at t=276
# routing rainfall at t=277
# routing rainfall at t=278
# routing rainfall at t=279
# routing rainfall at t=280
# routing rainfall at t=281
# routing rainfall at t=282
# routing rainfall at t=283
# routing rainfall at t=284
# routing rainfall at t=285
# routing rainfall at t=286
# routing rainfall at t=287
# routing rainfall at t=288
# routing rainfall at t=289
# routing rainfall at t=290
# routing rainfall at t=291
# routing rainfall at t=292
# routing rainfall at t=293
# routing rainfall at t=294
# routing rainfall at t=295
# routing rainfall at t=296
# routing rainfall at t=297
# routing rainfall at t=298
# routing rainfall at t=299
# routing rainfall at t=300
# routing rainfall at t=301
# routing rainfall at t=302
# routing rainfall at t=303
# routing rainfall at t=304
# routing rainfall at t=305
# routing rainfall at t=306
# routing rainfall at t=307
# routing rainfall at t=308
# routing rainfall at t=309
# routing rainfall at t=310
# routing rainfall at t=311
# routing rainfall at t=312
# routing rainfall at t=313
# routing rainfall at t=314
# routing rainfall at t=315
# routing rainfall at t=316
# routing rainfall at t=317
# routing rainfall at t=318
# routing rainfall at t=319
# routing rainfall at t=320
# routing rainfall at t=321
# routing rainfall at t=322
# routing rainfall at t=323
# routing rainfall at t=324
# routing rainfall at t=325
# routing rainfall at t=326
# routing rainfall at t=327
# routing rainfall at t=328
# routing rainfall at t=329
# routing rainfall at t=330
# routing rainfall at t=331
# routing rainfall at t=332
# routing rainfall at t=333
# routing rainfall at t=334
# routing rainfall at t=335
# routing rainfall at t=336
# routing rainfall at t=337
# routing rainfall at t=338
# routing rainfall at t=339
# routing rainfall at t=340
# routing rainfall at t=341
# routing rainfall at t=342
# routing rainfall at t=343
# routing rainfall at t=344
# routing rainfall at t=345
# routing rainfall at t=346
# routing rainfall at t=347
# routing rainfall at t=348
# routing rainfall at t=349
# routing rainfall at t=350
# routing rainfall at t=351
# routing rainfall at t=352
# routing rainfall at t=353
# routing rainfall at t=354
# routing rainfall at t=355
# routing rainfall at t=356
# routing rainfall at t=357
# routing rainfall at t=358
# routing rainfall at t=359
# routing rainfall at t=360
# routing rainfall at t=361
# routing rainfall at t=362
# routing rainfall at t=363
# routing rainfall at t=364

# %%
data = netCDF4.Dataset('overland.nc', 'r')
data.variables['surface_water__depth'][:,:,3]
# Out:
# masked_array(data =
#  [[ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]
#  [ 0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726  0.0008726  0.0008726
#    0.0008726  0.0008726  0.0008726  0.0008726]],
#              mask =
#  False,
#        fill_value = 1e+20)

# %% [markdown]
# landlab version 2.2.0
